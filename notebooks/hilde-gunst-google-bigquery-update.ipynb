# %%
import pandas as pd

# %%
from google.cloud import bigquery

# %%
client = bigquery.Client(project="ordinal-nucleus-405213")

sql = """
    SELECT * FROM `da-project-406614.finalise_df_master.master_draft1`
"""

df = client.query(sql).to_dataframe()
# Out:
# /home/ruth/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/google/auth/_default.py:83: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
df
# Out:
#           id               Scientific_Name  \
# 0         88  &dagger;scaniornis lundgreni
# 1         44  abrolhos painted buttonquail
# 2       9369              acanthis cabaret
# 3      10147           acanthis hornemanni
# 4       7470           accipiter chilensis
# ...      ...                           ...
# 10977  10972                     tyto alba
# 10978   9793            volatinia jacarina
# 10979   9168                xolmis irupero
# 10980   9579            zenaida auriculata
# 10981  10790              zenaida macroura
#
#                               Common_Name   size Size_category    Mass  \
# 0                                    None    NaN          None     NaN
# 1                                    None    NaN          None     NaN
# 2                                    None    NaN          None     NaN
# 3                                    None    NaN          None     NaN
# 4                                    None    NaN          None     NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10982 entries, 0 to 10981
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              10982 non-null  int64
#  1   Scientific_Name                 10982 non-null  object
#  2   Common_Name                     9141 non-null   object
#  3   size                            9141 non-null   float64
#  4   Size_category                   9141 non-null   object
#  5   Mass                            9141 non-null   float64
#  6   Habitat                         9141 non-null   object
#  7   Habitat_Category                9141 non-null   object
#  8   Migration                       9141 non-null   object
#  9   Trophic_Level__Feeding_Habits_  9141 non-null   object
#  10  Min_Latitude                    9141 non-null   object
#  11  Max_Latitude                    9141 non-null   object
# ...

# %%
df.shape
# Out:
# (10982, 18)

# %%
df.isna().sum()
# Out:
# id                                   0
# Scientific_Name                      0
# Common_Name                       1841
# size                              1841
# Size_category                     1841
# Mass                              1841
# Habitat                           1841
# Habitat_Category                  1841
# Migration                         1841
# Trophic_Level__Feeding_Habits_    1841
# Min_Latitude                      1841
# Max_Latitude                      1841
# Centroid_Latitude                 1841
# Centroid_Longitude                1842
# Range_Size                        1841
# General_Describtion               2270
# species_status                    1841
# status                               0
# dtype: int64

# %%
df = df.fillna(0)

# %%
df
# Out:
#           id               Scientific_Name  \
# 0         88  &dagger;scaniornis lundgreni
# 1         44  abrolhos painted buttonquail
# 2       9369              acanthis cabaret
# 3      10147           acanthis hornemanni
# 4       7470           accipiter chilensis
# ...      ...                           ...
# 10977  10972                     tyto alba
# 10978   9793            volatinia jacarina
# 10979   9168                xolmis irupero
# 10980   9579            zenaida auriculata
# 10981  10790              zenaida macroura
#
#                               Common_Name   size Size_category    Mass  \
# 0                                       0    0.0             0    0.00
# 1                                       0    0.0             0    0.00
# 2                                       0    0.0             0    0.00
# 3                                       0    0.0             0    0.00
# 4                                       0    0.0             0    0.00
# ...

# %%
df.isna().sum()
# Out:
# id                                0
# Scientific_Name                   0
# Common_Name                       0
# size                              0
# Size_category                     0
# Mass                              0
# Habitat                           0
# Habitat_Category                  0
# Migration                         0
# Trophic_Level__Feeding_Habits_    0
# Min_Latitude                      0
# Max_Latitude                      0
# Centroid_Latitude                 0
# Centroid_Longitude                0
# Range_Size                        0
# General_Describtion               0
# species_status                    0
# status                            0
# dtype: int64

# %%
! pwd
# Out:
# /home/ruth/code/brunothormaehlen/birdies/notebooks

# %%
df.to_csv('warehouse_231201-1523.csv')

# %%
df.columns
# Out:
# Index(['id', 'Scientific_Name', 'Common_Name', 'size', 'Size_category', 'Mass',
#        'Habitat', 'Habitat_Category', 'Migration',
#        'Trophic_Level__Feeding_Habits_', 'Min_Latitude', 'Max_Latitude',
#        'Centroid_Latitude', 'Centroid_Longitude', 'Range_Size',
#        'General_Describtion', 'species_status', 'status'],
#       dtype='object')

# %%
species_full = pd.read_csv("../bird_data/bird_species.csv")

# %%
species_full
# Out:
#        species_no           scientific_name   species_id
# 0               1    lithoptila abdounensis  /m/0100hjcf
# 1               2    kurrartapu johnnguyeni  /m/010hmtwz
# 2               3           zosterops kirki  /m/011l7vvz
# 3               4         emberiza goslingi  /m/011py2_8
# 4               5  bambolinetta lignitifila  /m/01264yxh
# ...           ...                       ...          ...
# 10977       10978         aquila chrysaetos     /m/0m41v
# 10978       10979                   mallard    /m/01hjj1
# 10979       10980                bald eagle     /m/01dx8
# 10980       10981          struthio camelus     /m/05n4y
# 10981       10982  gallus gallus domesticus     /m/09b5t
#
# [10982 rows x 3 columns]

# %%
augmented_warehouse = pd.merge(species_full, df_full, left_on = "species_no", right_on = "id", how = "left")

# %%
augmented_warehouse.to_csv('../bird_data/augmented_warehouse.csv')

# %%
augmented_warehouse
# Out:
#        species_no           scientific_name   species_id       id  \
# 0               1    lithoptila abdounensis  /m/0100hjcf      NaN
# 1               2    kurrartapu johnnguyeni  /m/010hmtwz      NaN
# 2               3           zosterops kirki  /m/011l7vvz      3.0
# 3               4         emberiza goslingi  /m/011py2_8      4.0
# 4               5  bambolinetta lignitifila  /m/01264yxh      NaN
# ...           ...                       ...          ...      ...
# 10977       10978         aquila chrysaetos     /m/0m41v  10978.0
# 10978       10979                   mallard    /m/01hjj1      NaN
# 10979       10980                bald eagle     /m/01dx8      NaN
# 10980       10981          struthio camelus     /m/05n4y  10981.0
# 10981       10982  gallus gallus domesticus     /m/09b5t      NaN
#
#          Scientific_Name    size Size_category       Mass    Habitat  \
# 0                    NaN     NaN           NaN        NaN        NaN
# ...

# %%
augmented_warehouse[augmented_warehouse.index == 1043]['General_Describtion'].iloc[0]
# Out:
# 'The pearl-bellied white-eye (Zosterops grayi) is a species of bird in the family Zosteropidae. It is native to the Kai Islands in Indonesia.'

# %%
augmented_warehouse[augmented_warehouse.index == 10979]['General_Describtion'].iloc[0]
# Out:
# nan
