# %%
import pandas as pd

# %%
from google.cloud import bigquery

# %%
client = bigquery.Client(project="ordinal-nucleus-405213")

sql = """
    SELECT * FROM `da-project-406614.Deliverable_Data.bird_data_master`
"""

df = client.query(sql).to_dataframe()
# Out:
# /home/ruth/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/google/auth/_default.py:83: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
df
# Out:
#        species_no       scientific_name                Common_Name     size  \
# 0            4807  oenanthe lugentoides                    unknown       46
# 1            3883    delichon nipalense         Nepal House-Martin      146
# 2            7350      sitta tephronota      Eastern Rock-Nuthatch      166
# 3            4675      amytornis housei            Black Grasswren      196
# 4            8312  carpodacus rubicilla  Caucasian Great-Rosefinch      221
# ...           ...                   ...                        ...      ...
# 10977       10857        cathartes aura             Turkey Vulture    806.5
# 10978       10060      sarcogyps calvus         Red-headed Vulture    914.2
# 10979       10870         corvus cornix                    unknown   155.25
# 10980        6513   oryzoborus funereus                    unknown   33.425
# 10981        2407    tyto deroepstorffi                    unknown  108.925
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10982 entries, 0 to 10981
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   species_no           10982 non-null  int64
#  1   scientific_name      10982 non-null  object
#  2   Common_Name          10982 non-null  object
#  3   size                 10982 non-null  object
#  4   Size_category        10982 non-null  object
#  5   Mass                 10982 non-null  object
#  6   Habitat              10982 non-null  object
#  7   habitat_category     10982 non-null  object
#  8   Migration            10982 non-null  object
#  9   Trophic_Level        10982 non-null  object
#  10  Min_Latitude         10982 non-null  object
#  11  Max_Latitude         10982 non-null  object
#  12  Centroid_Latitude    10982 non-null  object
#  13  Centroid_Longitude   10982 non-null  object
#  14  Range_Size           10982 non-null  object
# ...

# %%
df.shape
# Out:
# (10982, 19)

# %%
df.isna().sum()
# Out:
# species_no             0
# scientific_name        0
# Common_Name            0
# size                   0
# Size_category          0
# Mass                   0
# Habitat                0
# habitat_category       0
# Migration              0
# Trophic_Level          0
# Min_Latitude           0
# Max_Latitude           0
# Centroid_Latitude      0
# Centroid_Longitude     0
# Range_Size             0
# General_Description    0
# species_status         0
# status                 0
# sound_url              0
# dtype: int64

# %%
df['Migration'].value_counts()
# Out:
# Sedentary              8090
# Partially migratory    1151
# Migratory               934
# unknown                 807
# Name: Migration, dtype: int64

# %%
df
# Out:
#        species_no       scientific_name                Common_Name     size  \
# 0            4807  oenanthe lugentoides                    unknown       46
# 1            3883    delichon nipalense         Nepal House-Martin      146
# 2            7350      sitta tephronota      Eastern Rock-Nuthatch      166
# 3            4675      amytornis housei            Black Grasswren      196
# 4            8312  carpodacus rubicilla  Caucasian Great-Rosefinch      221
# ...           ...                   ...                        ...      ...
# 10977       10857        cathartes aura             Turkey Vulture    806.5
# 10978       10060      sarcogyps calvus         Red-headed Vulture    914.2
# 10979       10870         corvus cornix                    unknown   155.25
# 10980        6513   oryzoborus funereus                    unknown   33.425
# 10981        2407    tyto deroepstorffi                    unknown  108.925
#
# ...

# %%
df
# Out:
#        species_no       scientific_name                Common_Name     size  \
# 0            4807  oenanthe lugentoides                    unknown       46
# 1            3883    delichon nipalense         Nepal House-Martin      146
# 2            7350      sitta tephronota      Eastern Rock-Nuthatch      166
# 3            4675      amytornis housei            Black Grasswren      196
# 4            8312  carpodacus rubicilla  Caucasian Great-Rosefinch      221
# ...           ...                   ...                        ...      ...
# 10977       10857        cathartes aura             Turkey Vulture    806.5
# 10978       10060      sarcogyps calvus         Red-headed Vulture    914.2
# 10979       10870         corvus cornix                    unknown   155.25
# 10980        6513   oryzoborus funereus                    unknown   33.425
# 10981        2407    tyto deroepstorffi                    unknown  108.925
#
# ...

# %%
! pwd
# Out:
# /home/ruth/code/brunothormaehlen/birdies/notebooks

# %%
df.to_csv('warehouse_231205-1147.csv')

# %%
df.columns
# Out:
# Index(['species_no', 'scientific_name', 'Common_Name', 'size', 'Size_category',
#        'Mass', 'Habitat', 'habitat_category', 'Migration', 'Trophic_Level',
#        'Min_Latitude', 'Max_Latitude', 'Centroid_Latitude',
#        'Centroid_Longitude', 'Range_Size', 'General_Description',
#        'species_status', 'status', 'sound_url'],
#       dtype='object')

# %%
warehouse_df = pd.read_csv('../bird_data/warehouse_231205-1147.csv').set_index('species_no')

# %%
warehouse_df.columns
# Out:
# Index(['Unnamed: 0', 'scientific_name', 'Common_Name', 'size', 'Size_category',
#        'Mass', 'Habitat', 'habitat_category', 'Migration', 'Trophic_Level',
#        'Min_Latitude', 'Max_Latitude', 'Centroid_Latitude',
#        'Centroid_Longitude', 'Range_Size', 'General_Description',
#        'species_status', 'status', 'sound_url'],
#       dtype='object')

# %%
warehouse_df
# Out:
#             Unnamed: 0       scientific_name                Common_Name  \
# species_no
# 4807                 0  oenanthe lugentoides                    unknown
# 3883                 1    delichon nipalense         Nepal House-Martin
# 7350                 2      sitta tephronota      Eastern Rock-Nuthatch
# 4675                 3      amytornis housei            Black Grasswren
# 8312                 4  carpodacus rubicilla  Caucasian Great-Rosefinch
# ...                ...                   ...                        ...
# 10857            10977        cathartes aura             Turkey Vulture
# 10060            10978      sarcogyps calvus         Red-headed Vulture
# 10870            10979         corvus cornix                    unknown
# 6513             10980   oryzoborus funereus                    unknown
# 2407             10981    tyto deroepstorffi                    unknown
#
#                size Size_category     Mass         Habitat  \
# species_no
# ...
