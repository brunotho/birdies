# %%
import pandas as pd
import requests
from io import StringIO

# %% [markdown]
# # Importing the bird_master_df

# %%
# %%time

bird_master_df = pd.read_csv('../data_sourcing/bird_master_df.csv')

bird_master_df = bird_master_df.drop(columns='Unnamed: 0')

bird_master_df
# Out:
# CPU times: user 15 s, sys: 2.09 s, total: 17.1 s
# Wall time: 17.6 s
#                                                   image_url  image_id  \
# 0         http://www.taenos.com/img/ITIS/Dacnis-lineata-...         1
# 1         http://41.media.tumblr.com/tumblr_m81kchMiQn1r...      8100
# 2         http://madarbarat-lexikon.hu/images/dacnis%20c...     17844
# 3         http://t3.gstatic.com/images?q=tbn:ANd9GcSG87H...     20557
# 4         https://c2.staticflickr.com/4/3836/14737184263...     22123
# ...                                                     ...       ...
# 10357814  http://c5.statcounter.com/counter.php?sc_proje...   3371585
# 10357815   https://c.statcounter.com/10601132/0/b39882cb/0/   3371585
# 10357816  http://i74.servimg.com/u/f74/15/84/98/82/final...   3767414
# 10357817  http://ecx.images-amazon.com/images/I/513ReDIt...   4612387
# 10357818  http://t0.gstatic.com/images?q=tbn:ANd9GcR-za0...   4651952
#
#               scientific_name  species_no
# 0              dacnis lineata        7319
# 1              dacnis lineata        7319
# 2              dacnis lineata        7319
# 3              dacnis lineata        7319
# 4              dacnis lineata        7319
# ...                       ...         ...
# 10357814  scolopax rosenbergi         181
# 10357815  scolopax rosenbergi         181
# 10357816  scolopax rosenbergi         181
# 10357817  scolopax rosenbergi         181
# 10357818  scolopax rosenbergi         181
#
# [10357819 rows x 4 columns]

# %% [markdown]
# # Importing the MVP #1 selection

# %%
# Importing list of selected birds provided by the DATA ANALYTICS team

fp_select = '../data_sourcing/bird_selection.csv'

selected_birds_df = pd.read_csv(fp_select, delimiter=',')

columns_tbd = ['']

# Rename the second column to 'scientific_name'
selected_birds_df = selected_birds_df.rename(columns={'scientific name': 'scientific_name','id': 'species_no'})

selected_birds_df = selected_birds_df[['species_no', 'scientific_name']]

# Display the modified DataFrame
selected_birds_df
# Out:
#    species_no                      scientific_name
# 0       10705              geococcyx californianus
# 1       10923                cardinalis cardinalis
# 2       10381                  fregata magnificens
# 3        4652                 icterus pyrrhopterus
# 4        9402                      buteo plagiatus
# 5        6142  chlamydotis undulata fuertaventurae
# 6        1084             prioniturus waterstradti
# 7        4067             myiobius sulphureipygius
# 8        3446                   icterus melanopsis
# 9       10873             trichoglossus moluccanus

# %%
# selected_birds_df.to_csv('selected_birds_df.csv', index=True)

# %%
selected_species_df = selected_birds_df.loc[0]
species = pd.DataFrame(selected_species_df).T
species
# Out:
#   species_no          scientific_name
# 0      10705  geococcyx californianus

# %%
check_df = bird_master_df[bird_master_df['species_no'] == species['species_no'].iloc[0]]
check_df
# Out:
#                                                  image_url  image_id  \
# 9944672  http://thumb101.shutterstock.com/display_pic_w...     42258
# 9944673                                         1165818422     42258
# 9944674  3/stock-photo-greater-roadrunner-geococcyx-cal...     42258
# 9944675  http://www.basinandrangewatch.org/images/Visit...     50208
# 9944676  http://askabiologist.asu.edu/aab_tools/_media/...     61754
# ...                                                    ...       ...
# 9945965  http://t2.gstatic.com/images?q=tbn:ANd9GcRyTdV...   4852653
# 9945966  http://s3.amazonaws.com/birdfellow-production/...   4855995
# 9945967  http://s3.amazonaws.com/birdfellow-production/...   4855995
# 9945968  http://4.bp.blogspot.com/_WK_jlizEEBQ/Sd_iK1f_...   4862856
# 9945969  https://www.skullsunlimited.com/userfiles/imag...   4880984
#
#                  scientific_name  species_no
# 9944672  geococcyx californianus       10705
# 9944673  geococcyx californianus       10705
# 9944674  geococcyx californianus       10705
# 9944675  geococcyx californianus       10705
# 9944676  geococcyx californianus       10705
# ...                          ...         ...
# 9945965  geococcyx californianus       10705
# 9945966  geococcyx californianus       10705
# 9945967  geococcyx californianus       10705
# 9945968  geococcyx californianus       10705
# 9945969  geococcyx californianus       10705
#
# [1298 rows x 4 columns]

# %%
check_df['image_id'].nunique()
# Out:
# 683

# %%
check2 = check_df.copy()
check2
# Out:
#          Unnamed: 0                                          image_url  \
# 9944672     9944672  http://thumb101.shutterstock.com/display_pic_w...
# 9944673     9944673                                         1165818422
# 9944674     9944674  3/stock-photo-greater-roadrunner-geococcyx-cal...
# 9944675     9944675  http://www.basinandrangewatch.org/images/Visit...
# 9944676     9944676  http://askabiologist.asu.edu/aab_tools/_media/...
# ...             ...                                                ...
# 9945965     9945965  http://t2.gstatic.com/images?q=tbn:ANd9GcRyTdV...
# 9945966     9945966  http://s3.amazonaws.com/birdfellow-production/...
# 9945967     9945967  http://s3.amazonaws.com/birdfellow-production/...
# 9945968     9945968  http://4.bp.blogspot.com/_WK_jlizEEBQ/Sd_iK1f_...
# 9945969     9945969  https://www.skullsunlimited.com/userfiles/imag...
#
#          image_id          scientific_name  species_no
# 9944672     42258  geococcyx californianus       10705
# 9944673     42258  geococcyx californianus       10705
# 9944674     42258  geococcyx californianus       10705
# 9944675     50208  geococcyx californianus       10705
# 9944676     61754  geococcyx californianus       10705
# ...           ...                      ...         ...
# 9945965   4852653  geococcyx californianus       10705
# 9945966   4855995  geococcyx californianus       10705
# 9945967   4855995  geococcyx californianus       10705
# 9945968   4862856  geococcyx californianus       10705
# 9945969   4880984  geococcyx californianus       10705
#
# [1298 rows x 5 columns]

# %%
check2 = check2[check2['image_id'] != 61754]
check2
# Out:
#          Unnamed: 0                                          image_url  \
# 9944675     9944675  http://www.basinandrangewatch.org/images/Visit...
# 9944678     9944678  http://t1.gstatic.com/images?q=tbn:ANd9GcRufkh...
# 9944679     9944679  http://t2.gstatic.com/images?q=tbn:ANd9GcQPkLE...
# 9944680     9944680  http://t3.gstatic.com/images?q=tbn:ANd9GcQmwqt...
# 9944681     9944681  http://farm9.static.flickr.com/8653/1610863804...
# ...             ...                                                ...
# 9945965     9945965  http://t2.gstatic.com/images?q=tbn:ANd9GcRyTdV...
# 9945966     9945966  http://s3.amazonaws.com/birdfellow-production/...
# 9945967     9945967  http://s3.amazonaws.com/birdfellow-production/...
# 9945968     9945968  http://4.bp.blogspot.com/_WK_jlizEEBQ/Sd_iK1f_...
# 9945969     9945969  https://www.skullsunlimited.com/userfiles/imag...
#
#          image_id          scientific_name  species_no
# 9944675     50208  geococcyx californianus       10705
# 9944678     91198  geococcyx californianus       10705
# 9944679    103434  geococcyx californianus       10705
# 9944680    107041  geococcyx californianus       10705
# 9944681    109541  geococcyx californianus       10705
# ...           ...                      ...         ...
# 9945965   4852653  geococcyx californianus       10705
# 9945966   4855995  geococcyx californianus       10705
# 9945967   4855995  geococcyx californianus       10705
# 9945968   4862856  geococcyx californianus       10705
# 9945969   4880984  geococcyx californianus       10705
#
# [1293 rows x 5 columns]

# %% [markdown]
# # Data retrieval function

# %%
#### Current best shot!

import os
import requests
from PIL import Image
from io import BytesIO

def image_retrieval(bird_master_df, selected_birds_df, mydir=None, size = (256, 256), number = 1):
    
    # Temporary merged data frame based on a filtered version of bird_master_df
    temp_df = bird_master_df[bird_master_df['species_no'] == selected_birds_df['species_no'].iloc[0]]

    temp_list = []
    
    # Iterate over rows in temp_df
    for index, row in temp_df.iterrows():

        if row['image_id'] in temp_list:
            continue
        
        # Locate download links
        url_im = row['image_url']

        # Attempt download via link ('image_url') from temp_df
        try:
            response = requests.get(url_im)

        except:
            pass

        # Check if the download was successful
        if response.status_code == 200:
            
            try:
                im = Image.open(BytesIO(response.content))
            
                # Resize image using im.thumbnail(size, Image.ANTIALIAS) with 256 as the maximum dimension while keeping original image proportions
                im.thumbnail(size, Image.LANCZOS)
                
                # Create folder if it doesn't exist
                if mydir is None:
                    mydir = os.getcwd()
                    species_folder = os.path.join(mydir, f"{row['species_no']}")
                    os.makedirs(species_folder, exist_ok=True)
    
                # Save resulting image via im.save as [species_no]_[xxxx].png in the corresponding folder created above
                im_dir = os.path.join(species_folder, f"{row['species_no']}_{number:04d}.png")
                
                # Check if the file already exists, if not, save the image
                if not os.path.exists(im_dir):
                    im.save(im_dir)

                    ## remove duplicate image_ids from temp_df

                    
                    temp_list.append(row['image_id'])
                    
                    # 1. retrieve image_id of successfully saved image
                    #temp_img_id = row['image_id']
                    
                    # 2. Update temp_df and delete all rows below with matching image_id
                    # selec_birds_df.drop(0, inplace=True)
                    #temp_df = temp_df[temp_df['image_id'] != temp_img_id]
                    
                    print(f"Saved: {im_dir}")
                else:
                    print(f"Skipped (already exists): {im_dir}")
                
                # Increment the numbering variable for the next image
                number += 1
            
            except:
                
                pass

# %%
image_retrieval(check_df, species)
# Out:
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0001.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0002.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0003.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0004.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0005.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0006.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0007.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0008.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0009.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0010.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0011.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0012.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0013.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0014.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0015.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0016.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0017.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0018.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0019.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0020.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0021.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0022.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0023.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0024.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0025.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0026.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0027.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0028.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0029.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0030.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0031.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0032.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0033.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0034.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0035.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0036.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0037.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0038.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0039.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0040.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0041.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0042.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0043.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0044.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0045.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0046.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0047.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0048.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0049.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0050.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0051.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0052.png
# Saved: /Users/tristanspilker/code/brunothormaehlen/birdies/notebooks/10705/10705_0053.png
