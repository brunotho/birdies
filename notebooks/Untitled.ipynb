# %% [markdown]
# # 50 species that made it into the model

# %%
import pandas as pd

# %%
class_names = ['2091', '10024', '10154', '10279', '10382', '10460', '10474', '10491',
               '10512', '10517', '10527', '10542', '10569', '10588', '10592', '10627',
               '10636', '10644', '10657', '10692', '10694', '10703', '10705', '10720',
               '10759', '10796', '10804', '10808', '10823', '10828', '10833', '10841',
               '10848', '10883', '10896', '10921', '10939', '10944', '10949', '10952',
               '10966', '7980', '8643', '9042', '9149', '9463', '9547', '9763', '9944', '9980']

# %%
our_50_df = pd.DataFrame(class_names, columns=['species_no']).astype(int)
our_50_df
# Out:
#     species_no
# 0         2091
# 1        10024
# 2        10154
# 3        10279
# 4        10382
# 5        10460
# 6        10474
# 7        10491
# 8        10512
# 9        10517
# 10       10527
# 11       10542
# 12       10569
# 13       10588
# 14       10592
# 15       10627
# 16       10636
# 17       10644
# 18       10657
# 19       10692
# 20       10694
# 21       10703
# 22       10705
# 23       10720
# 24       10759
# 25       10796
# 26       10804
# 27       10808
# 28       10823
# 29       10828
# 30       10833
# 31       10841
# 32       10848
# 33       10883
# 34       10896
# 35       10921
# 36       10939
# 37       10944
# 38       10949
# 39       10952
# 40       10966
# 41        7980
# 42        8643
# 43        9042
# 44        9149
# 45        9463
# 46        9547
# 47        9763
# 48        9944
# 49        9980

# %%
our_50_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   species_no  50 non-null     int64
# dtypes: int64(1)
# memory usage: 528.0 bytes

# %%
filepath = '/Users/tristanspilker/code/brunothormaehlen/birdies/bird_data/warehouse_231205-1147.csv'

warehouse_df = pd.read_csv(filepath)

# %%
warehouse_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10982 entries, 0 to 10981
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           10982 non-null  int64
#  1   species_no           10982 non-null  int64
#  2   scientific_name      10982 non-null  object
#  3   Common_Name          10982 non-null  object
#  4   size                 10982 non-null  object
#  5   Size_category        10982 non-null  object
#  6   Mass                 10982 non-null  object
#  7   Habitat              10982 non-null  object
#  8   habitat_category     10982 non-null  object
#  9   Migration            10982 non-null  object
#  10  Trophic_Level        10982 non-null  object
#  11  Min_Latitude         10982 non-null  object
#  12  Max_Latitude         10982 non-null  object
#  13  Centroid_Latitude    10982 non-null  object
#  14  Centroid_Longitude   10982 non-null  object
# ...

# %%
warehouse_df.head(5)
# Out:
#    Unnamed: 0  species_no       scientific_name                Common_Name  \
# 0           0        4807  oenanthe lugentoides                    unknown
# 1           1        3883    delichon nipalense         Nepal House-Martin
# 2           2        7350      sitta tephronota      Eastern Rock-Nuthatch
# 3           3        4675      amytornis housei            Black Grasswren
# 4           4        8312  carpodacus rubicilla  Caucasian Great-Rosefinch
#
#   size Size_category   Mass Habitat    habitat_category  Migration  \
# 0   46        Medium   22.4    Rock       Open habitats  Sedentary
# 1  146        Medium  14.96    Rock  Semi-open habitats  Migratory
# 2  166        Medium   35.2    Rock       Open habitats  Sedentary
# 3  196        Medium  28.92    Rock       Open habitats  Sedentary
# 4  221        Medium   43.2    Rock       Open habitats  Sedentary
#
#   Trophic_Level Min_Latitude Max_Latitude Centroid_Latitude  \
# ...

# %%
Fifty_species_in_model = pd.merge(our_50_df, warehouse_df, on='species_no', how='left')
Fifty_species_in_model = Fifty_species_in_model[['species_no','scientific_name','Common_Name','General_Description']]
Fifty_species_in_model = Fifty_species_in_model.sort_values('species_no').set_index('species_no')
Fifty_species_in_model
# Out:
#                           scientific_name  \
# species_no
# 2091                     corvus violaceus
# 7980                  carduelis corsicana
# 8643                       aethia pusilla
# 9042                      cyanopica cooki
# 9149               locustella fluviatilis
# 9463                      anthus petrosus
# 9547                   aethia cristatella
# 9763                 carduelis citrinella
# 9944              acrocephalus paludicola
# 9980                  lanius meridionalis
# 10024                 ficedula albicollis
# 10154              acrocephalus palustris
# 10279                      ficedula parva
# 10382                    larus glaucoides
# 10460                    alectoris graeca
# 10474                       gavia arctica
# 10491                       aythya nyroca
# 10512                      gavia stellata
# 10517                  certhia familiaris
# 10527                    anthus pratensis
# 10542                        larus fuscus
# ...

# %%
Fifty_species_in_model.to_csv('Fifty_species_in_model.csv')
